# %%
import pandas as pd
df=pd.read_csv("/content/Salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
df['discipline'].value_counts()
# Out:
# discipline
# B    42
# A    36
# Name: count, dtype: int64

# %%
df['discipline'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='discipline'>

# %%
#scater plot:it describes the relationship between the variables
ages=[36,67,45,56,58,35,26,27]
salary=[36000,45000,55000,65000,45000,30000,45000,60000]
plt.xlabel("Age of person")
plt.ylabel("salary of the person")
plt.title("salary distrubution of employees")
plt.scatter(ages,salary,color="red")

# %%
x=[-5,-4,-1,2,4,6,8,]
y=[20,34,38,46,49,54,68]
plt.figure(figsize=(6,4))
plt.suptitle("learning visualization",size=25)
plt.xlim(-10,10)
plt.ylim(10,100)
plt.plot(x,y)

# %%
#plot graph of nos(-100 to 100)and its square. use range function
a=list(range(-100,100))
b=[i*i for i in a]
plt.plot(a,b)

# %%
x
# Out:
# [-5, -4, -1, 2, 4, 6, 8]

# %%
y
# Out:
# [20, 34, 38, 46, 49, 54, 68]

# %%
from math import exp
x=list(range(0,20))
y=[exp(i) for i in x]
plt.plot(x,y)

# %%
#plot multiple plot
from math import *
plt.figure(figsize=(16,9))
x=list(range(-10,10))
y=[i*i for i in x]
plt.subplot(3,4,1)  #3X4 grid,1st position of graph

plt.plot(x,y)
plt.title("graph of squares")

z=[i*i*i for i in x]
plt.subplot(3,4,6) #8th position
plt.plot(x,z)
plt.title("Graph of cubes")

w=[sin(i) for i in x]
plt.subplot(3,4,12)#12th position
plt.plot(x,w)
plt.title("Graph of sin(x)")
# Out:
# Text(0.5, 1.0, 'Graph of sin(x)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("/content/mtcars.csv")
data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
data.shape
# Out:
# (32, 11)

# %%
pd.crosstab(data["cyl"],data["gear"])
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %%
pd.crosstab(data["gear"],data["cyl"]).plot(kind="bar")
# Out:
# <Axes: xlabel='gear'>

# %%
data["gear"].value_counts()
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
data["gear"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
#scatter plot between2 cold(mpg and qsec)
plt.scatter(data.mpg,data.qsec,color="red")

# %%
plt.hist(data.mpg,edgecolor="red",color="yellow")
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data.mpg,edgecolor="red",facecolor="green",bins=5)
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(data.mpg)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(data.mpg,vert=False,notch=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mtcars=pd.read_csv("/content/mtcars.csv")

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
mtcars.hist(figsize=(15,10),color="red")
plt.tight_layout()
plt.show()

# %%
plt.figure(facecolor="teal")
plt.scatter(mtcars.mpg,mtcars.qsec,color="red",marker="*")

# %%
plt.violinplot(mtcars.mpg)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
pd.crosstab(tips.smoker,tips.sex)
# Out:
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
pd.crosstab(tips.smoker,tips.sex).plot(kind="bar")
# Out:
# <Axes: xlabel='smoker'>

# %%
#seaborn plots
# strip plots
sns.stripplot(y="tip",data=tips,jitter=True)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.stripplot(x="sex",y="tip",data=tips,jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x="day",y="tip",data=tips,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day",y="tip",data=tips,jitter=True, size=3)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#swarm plot
sns.swarmplot(x="day",y="tip",data=tips,size=6)
plt.ylabel("tip($)")
# Out:
# Text(47.097222222222214, 0.5, 'tip($)')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="day",y="tip",data=tips,size=6,hue="sex")
plt.ylabel("tip($)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="day",y="tip",data=tips,size=6,hue="time")
plt.ylabel("tip($)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#subplot
plt.subplot(2,2,1)
sns.boxplot(x="day",y="tip",data=tips)

plt.subplot(2,2,2)
sns.barplot(x="day",y="tip",data=tips)
plt.ylabel("tips($)")
plt.title("boxplot of tips")


plt.subplot(2,2,3)
sns.violinplot(x="day",y="tip",data=tips)

plt.subplot(2,2,4)
sns.swarmplot(x="day",y="tip",data=tips)
plt.ylabel("tips($)")
plt.title("violint of tips")
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 25.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 26.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 27.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 29.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(x="total_bill",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x="tip",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#joint plot- scatter plot and individual histogram of x and y variable

sns.jointplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
pd.plotting.scatter_matrix(tips)
# Out:
# array([[<Axes: xlabel='total_bill', ylabel='total_bill'>,
#         <Axes: xlabel='tip', ylabel='total_bill'>,
#         <Axes: xlabel='size', ylabel='total_bill'>],
#        [<Axes: xlabel='total_bill', ylabel='tip'>,
#         <Axes: xlabel='tip', ylabel='tip'>,
#         <Axes: xlabel='size', ylabel='tip'>],
#        [<Axes: xlabel='total_bill', ylabel='size'>,
#         <Axes: xlabel='tip', ylabel='size'>,
#         <Axes: xlabel='size', ylabel='size'>]], dtype=object)

# %%
#pair plot: if dataset has many numeric columns, you can plot many plots of different combination using pairplot
#diagonally it gives histo or barplot of individual plot of total_bill, tip and size
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips,hue='sex')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/content/train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.shape
# Out:
# (891, 12)

# %%
data.groupby("Survived")["PassengerId"].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
data.groupby(["Survived","Sex"])["PassengerId"].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: PassengerId, dtype: int64

# %%
pd.crosstab(data["Survived"],data["Sex"])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(data["Survived"],data["Sex"]).plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Survived",y="Age",data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Sex",y="Survived",data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Sex",y="Age",data=data,hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.barplot(x="Pclass",y="Survived",data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x="Pclass",y="Survived",data=data,hue="Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.distplot(data.loc[data["Survived"]==1,"Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(data)

# %%
#Pclass Vs Survived
grid=sns.FacetGrid(data,col="Survived",row="Pclass",height=2.4,aspect=1.6)
grid.map(plt.hist,"Age",alpha=0.9,bins=20)# alpha=shade of the graph, try alpha=0.1 or 0.9 range:0 to 1

# %%
fig,ax=plt.subplots(nrows=2,ncols=2)# empty spaces for plots, change nrows and ncols

# %%
#subplots(): creates a figure and a grid of subplots
#subplots()withought arguments returs afigure and a single axes
fig,ax=plt.subplots()
ages=[30,38,45,29,50,47]
salary=[30000,38000,40000,29000,60000,50000]
ax.plot(ages,salary)
ax.set_title("A single plot")
# Out:
# Text(0.5, 1.0, 'A single plot')

# %%
figbi, axesbi = plt.subplots(2,4, figsize=(18,10))
data.groupby("Pclass")["Survived"].mean().plot(kind="bar",ax=axesbi[0,0],xlim=[0,1])
data.groupby("SibSp")["Survived"].mean().plot(kind="bar",ax=axesbi[0,1],xlim=[0,1])
data.groupby("Parch")["Survived"].mean().plot(kind="bar",ax=axesbi[0,2],xlim=[0,1])
data.groupby("Sex")["Survived"].mean().plot(kind="bar",ax=axesbi[0,3],xlim=[0,1])
data.groupby("Embarked")["Survived"].mean().plot(kind="bar",ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived",y="Age",data=data, ax=axesbi[1,1])
sns.boxplot(x="Survived",y="Fare",data=data, ax=axesbi[1,2])
plt.show()
figbi.savefig("myfig.png") #or ("myfig.jpeg")
from google.colab import files
files.download("myfig.png")
