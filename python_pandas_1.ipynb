# %%
import pandas as pd
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...

# %%
df1=pd.read_csv("/content/Salaries.csv")
df1
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['phd'].plot(kind='hist', bins=20, title='phd')
# ...

# %%
df1.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df1.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df1["rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['phd'].plot(kind='hist', bins=20, title='phd')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['service'].plot(kind='hist', bins=20, title='service')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['salary'].plot(kind='hist', bins=20, title='salary')
# ...

# %%
df1.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df1.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df1.phd.mean()
# Out:
# 19.705128205128204

# %%
df1.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df1.phd.quantile(0.25)
# Out:
# 10.25

# %%
df1.phd.quantile(0.75)
# Out:
# 27.75

# %%
df1.phd.std()
# Out:
# 12.498424809175864

# %%
df_50=df1.head(50)
df_50
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df1.salary # it doesnot work if col name has blank space or dot eg
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df1["salary"]# it will work if col name has blank space or dot eg
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
  #2 data structures in pandas
  # 1> series: its a 1D array whose object size cannot be changed
  #
  # 2> Data Frame: its a 2D structure with cols and rows whose size can be changed

# %%
type(df1.salary)
# Out:
# pandas.core.series.Series

# %%
result2=df1[["salary","rank"]]
result2
# Out:
#     salary       rank
# 0   186960       Prof
# 1    93000       Prof
# 2   110515       Prof
# 3   131205       Prof
# 4   104800       Prof
# ..     ...        ...
# 73  105450       Prof
# 74  104542  AssocProf
# 75  124312       Prof
# 76  109954       Prof
# 77  109646       Prof
#
# [78 rows x 2 columns]

# %%
type(result2)
# Out:
# pandas.core.frame.DataFrame

# %%
# extract purticular columns in a new data frame
newdf=df1[["salary","service","phd"]]
newdf
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# ..     ...      ...  ...
# 73  105450       10   18
# 74  104542        6   19
# 75  124312       17   17
# 76  109954       14   28
# 77  109646       15   23
#
# [78 rows x 3 columns]

# %%
df1["discipline"].value_counts() #category and its value
# Out:
# discipline
# B    42
# A    36
# Name: count, dtype: int64

# %%
df1["rank"].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
# in rank 3 values: Asso,asst,Prof. group by this and find mean of each category
df1.groupby(["rank"]).salary.mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
df1.groupby(["discipline"]).count()
# Out:
#             rank  phd  service  sex  salary
# discipline
# A             36   36       36   36      36
# B             42   42       42   42      42

# %%
df1.groupby(["discipline","rank"]).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df1.groupby(["discipline","rank","sex"]).count()
# Out:
#                              phd  service  salary
# discipline rank      sex
# A          AssocProf Female    4        4       4
#                      Male      1        1       1
#            AsstProf  Female    6        6       6
#                      Male      2        2       2
#            Prof      Female    8        8       8
#                      Male     15       15      15
# B          AssocProf Female    6        6       6
#                      Male      2        2       2
#            AsstProf  Female    5        5       5
#                      Male      6        6       6
#            Prof      Female   10       10      10
#                      Male     13       13      13

# %%
df1.groupby(["discipline","rank","sex"]).mean()
# Out:
#                                    phd    service         salary
# discipline rank      sex
# A          AssocProf Female  18.500000  15.500000   72128.500000
#                      Male    20.000000  17.000000   81285.000000
#            AsstProf  Female   4.833333   2.500000   72933.333333
#                      Male     3.000000   1.000000   79000.000000
#            Prof      Female  26.500000  16.125000  109631.875000
#                      Male    28.933333  22.733333  113164.400000
# B          AssocProf Female  13.500000   8.833333   99435.666667
#                      Male    10.500000   7.500000  113404.000000
#            AsstProf  Female   6.600000   2.600000   84189.800000
#                      Male     4.666667   2.000000   88224.000000
#            Prof      Female  21.500000  17.900000  131836.200000
#                      Male    29.538462  25.846154  137989.076923

# %%
df1[df1.salary<120000]
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# ...

# %%
df1.shape
# Out:
# (78, 6)

# %%
df1.shape[0]
# Out:
# 78

# %%
df1.shape[1]
# Out:
# 6

# %%
df1[df1.salary>120000].shape[0]
# Out:
# 25

# %%
# Create a dataframe having all males whose salaryi > 1,50,000/-
newdf1=df1[(df1["sex"]=="Male") & (df1["salary"]>150000)]
newdf1
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
newdf1.count()
# Out:
# rank          7
# discipline    7
# phd           7
# service       7
# sex           7
# salary        7
# dtype: int64

# %%
df1[(df1["service"]>15) | (df1["salary"]>100000)]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# ...

# %%
df1.iloc[56] # index location for row
# Out:
# rank          AssocProf
# discipline            A
# phd                  10
# service               8
# sex              Female
# salary            77500
# Name: 56, dtype: object

# %%
df1.iloc[1:4,0:3]
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df1.iloc[0:10,0:4]
# Out:
#         rank discipline  phd  service
# 0       Prof          B   56       49
# 1       Prof          A   12        6
# 2       Prof          A   23       20
# 3       Prof          A   40       31
# 4       Prof          B   20       18
# 5       Prof          A   20       20
# 6  AssocProf          A   20       17
# 7       Prof          A   18       18
# 8       Prof          A   29       19
# 9       Prof          A   51       51

# %%
df1.iloc[0:3,]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515

# %%
df1.iloc[:,2:3]
# Out:
#     phd
# 0    56
# 1    12
# 2    23
# 3    40
# 4    20
# ..  ...
# 73   18
# 74   19
# 75   17
# 76   28
# 77   23
#
# [78 rows x 1 columns]

# %%
df1.iloc[[10,20,26,30],]
# Out:
#          rank discipline  phd  service   sex  salary
# 10       Prof          B   39       33  Male  128250
# 20   AsstProf          B    4        4  Male   92000
# 26       Prof          A   38       19  Male  148750
# 30  AssocProf          B    9        7  Male  107008

# %%
df1.iloc[::5]#start value=0,endvalue=77, step value=5
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 5        Prof          A   20       20    Male  122400
# 10       Prof          B   39       33    Male  128250
# 15       Prof          B   17        3    Male  150480
# 20   AsstProf          B    4        4    Male   92000
# 25       Prof          B   35       31    Male   99418
# 30  AssocProf          B    9        7    Male  107008
# 35       Prof          B   28       23    Male  126933
# 40       Prof          A   39       36  Female  137000
# 45       Prof          B   25       25  Female  140096
# 50   AsstProf          B   10        5  Female   97032
# 55   AsstProf          A    2        0  Female   72500
# 60   AsstProf          B    3        3  Female   92000
# 65       Prof          A   36       19  Female  117555
# 70   AsstProf          A    8        3  Female   78500
# 75       Prof          B   17       17  Female  124312

# %%
df1.iloc[::-1]
# Out:
#          rank discipline  phd  service     sex  salary
# 77       Prof          A   23       15  Female  109646
# 76       Prof          A   28       14  Female  109954
# 75       Prof          B   17       17  Female  124312
# 74  AssocProf          B   19        6  Female  104542
# 73       Prof          B   18       10  Female  105450
# ..        ...        ...  ...      ...     ...     ...
# 4        Prof          B   20       18    Male  104800
# 3        Prof          A   40       31    Male  131205
# 2        Prof          A   23       20    Male  110515
# 1        Prof          A   12        6    Male   93000
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %%
df1.loc[:,["rank","sex"]] # withouhght mentioning index no - mentioning col name
# Out:
#          rank     sex
# 0        Prof    Male
# 1        Prof    Male
# 2        Prof    Male
# 3        Prof    Male
# 4        Prof    Male
# ..        ...     ...
# 73       Prof  Female
# 74  AssocProf  Female
# 75       Prof  Female
# 76       Prof  Female
# 77       Prof  Female
#
# [78 rows x 2 columns]

# %%
df.loc[[1,35,45],["sex","salary"]]
# Out:
#        sex  salary
# 1     Male   93000
# 35    Male  126933
# 45  Female  140096
